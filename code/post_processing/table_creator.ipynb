# %%
import pandas as pd

# %%
REPORT_PATH = "../../data/results/"

# %%
forest_test_200_data = pd.read_csv(REPORT_PATH + "forest-test_200.csv")
forest_test_200_data.head(20)
# Out:
#                                         description    rmse  rmse_variance  \
# 0   Random Forest Regression, where n_estimators=25  1.9673         0.5504
# 1   Random Forest Regression, where n_estimators=50  1.9125         0.5166
# 2  Random Forest Regression, where n_estimators=100  1.9009         0.5819
# 3  Random Forest Regression, where n_estimators=150  1.8891         0.5056
# 4  Random Forest Regression, where n_estimators=200  1.9023         0.5105
# 5  Random Forest Regression, where n_estimators=250  1.8905         0.5240
# 6  Random Forest Regression, where n_estimators=300  1.9094         0.5062
# 7  Random Forest Regression, where n_estimators=350  1.9250         0.5738
#
#       mse  mse_variance      r2  r2_variance  num_records_analyzed  \
# 0  4.1731        2.2666  0.8678       0.0604                   200
# 1  3.9246        2.2108  0.8813       0.0277                   200
# 2  3.9519        2.4721  0.8843       0.0299                   200
# ...

# %%
forest_test_4011_data = pd.read_csv(REPORT_PATH + "forest-test_4011.csv")
forest_test_4011_data.head(200)
# Out:
#                                         description    rmse  rmse_variance  \
# 0   Random Forest Regression, where n_estimators=25  0.7934         0.0763
# 1   Random Forest Regression, where n_estimators=50  0.8050         0.0601
# 2  Random Forest Regression, where n_estimators=100  0.7813         0.0649
# 3  Random Forest Regression, where n_estimators=150  0.7919         0.0760
# 4  Random Forest Regression, where n_estimators=200  0.7920         0.0705
# 5  Random Forest Regression, where n_estimators=250  0.7938         0.0698
# 6  Random Forest Regression, where n_estimators=300  0.7862         0.0682
# 7  Random Forest Regression, where n_estimators=350  0.7838         0.0725
#
#       mse  mse_variance      r2  r2_variance  num_records_analyzed  \
# 0  0.6353        0.1155  0.9821       0.0024                  4011
# 1  0.6516        0.0927  0.9816       0.0016                  4011
# 2  0.6147        0.0971  0.9827       0.0018                  4011
# ...

# %%
k_test_results_200_data = pd.read_csv(REPORT_PATH + "k-test-results_200.csv")
k_test_results_200_data.head(200)
# Out:
#                     description    rmse  rmse_variance      mse  mse_variance  \
# 0    KNN Regressor, where K = 1  3.0416         0.6953   9.7350        4.2872
# 1    KNN Regressor, where K = 2  3.0341         0.8948  10.0062        4.9744
# 2    KNN Regressor, where K = 3  2.8754         0.9360   9.1439        5.0326
# 3    KNN Regressor, where K = 4  2.8586         0.7835   8.7853        4.0419
# 4    KNN Regressor, where K = 5  2.9796         0.7419   9.4286        4.4576
# 5    KNN Regressor, where K = 6  2.9434         0.8263   9.3463        4.9494
# 6    KNN Regressor, where K = 7  2.8734         0.8391   8.9606        5.0858
# 7    KNN Regressor, where K = 8  2.9270         0.8751   9.3331        5.4598
# 8    KNN Regressor, where K = 9  3.0105         0.9698  10.0038        6.2036
# 9   KNN Regressor, where K = 10  3.0636         0.9965  10.3785        6.5165
# 10  KNN Regressor, where K = 11  3.0666         1.0148  10.4340        6.8170
# ...

# %%
k_test_results_4011_data = pd.read_csv(REPORT_PATH + "k-test-results_4011.csv")
k_test_results_4011_data.head(200)
# Out:
#                     description    rmse  rmse_variance     mse  mse_variance  \
# 0    KNN Regressor, where K = 1  2.4516         0.1245  6.0259        0.6042
# 1    KNN Regressor, where K = 2  2.2303         0.1812  5.0070        0.7926
# 2    KNN Regressor, where K = 3  2.1945         0.1714  4.8451        0.7561
# 3    KNN Regressor, where K = 4  2.2076         0.1838  4.9071        0.8121
# 4    KNN Regressor, where K = 5  2.2127         0.1888  4.9315        0.8292
# 5    KNN Regressor, where K = 6  2.2209         0.1707  4.9614        0.7554
# 6    KNN Regressor, where K = 7  2.2190         0.1763  4.9550        0.7768
# 7    KNN Regressor, where K = 8  2.2280         0.1759  4.9949        0.7784
# 8    KNN Regressor, where K = 9  2.2278         0.1771  4.9943        0.7868
# 9   KNN Regressor, where K = 10  2.2393         0.1763  5.0457        0.7875
# 10  KNN Regressor, where K = 11  2.2383         0.1893  5.0460        0.8434
# ...

# %%
all_data = pd.read_csv(REPORT_PATH + "all_models_performance.csv")
all_data.head(200)
# Out:
#                                           description    rmse  rmse_variance  \
# 0    Random Forest Regression, where n_estimators=150  1.9053         0.5747
# 1                          KNN Regressor, where K = 4  2.8586         0.7835
# 2                          Multiple Linear Regression  0.0000         0.0000
# 3                            Decision Tree Regression  2.4385         1.0600
# 4   MLP Regression using Relu: 20 hidden layers wi...  0.3352         0.2973
# 5    Random Forest Regression, where n_estimators=150  1.6265         0.3819
# 6                          KNN Regressor, where K = 4  3.2327         0.6227
# 7                          Multiple Linear Regression  0.0000         0.0000
# 8                            Decision Tree Regression  2.5006         1.4162
# 9   MLP Regression using Relu: 20 hidden layers wi...  0.0662         0.0412
# 10   Random Forest Regression, where n_estimators=150  1.1860         0.1926
# ...
